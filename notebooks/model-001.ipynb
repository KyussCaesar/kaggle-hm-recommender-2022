# %% [markdown]
# # (baseline) Most Popular Articles
#
# Baseline model, just recommend the most popular articles over the training period.

# %%
# !pip install polars
# Out:
# Requirement already satisfied: polars in /opt/conda/lib/python3.9/site-packages (0.13.23)
# Requirement already satisfied: typing_extensions>=4.0.0 in /opt/conda/lib/python3.9/site-packages (from polars) (4.1.1)
# Requirement already satisfied: numpy>=1.16.0 in /opt/conda/lib/python3.9/site-packages (from polars) (1.21.5)

# %%
import os
os.chdir('/home/jovyan/work')

# %%
import polars as pl

# %%
import notebooks
from notebooks import data_storage

transactions = data_storage.load_dataset('transactions_train')

# %%
class MostPopularRecommender:
  def __init__(self, transactions: pl.DataFrame):
    self.transactions = transactions

  def get_recommendations(self, customer_ids: list, start_date, end_date) -> pl.DataFrame:
    most_popular = (
      transactions
      .lazy()
      .filter(
        (pl.col('t_dat') < end_date)
      & (pl.col('t_dat') > start_date)
      )
      .groupby('article_id')
      .agg([pl.count()])
      .sort('count', reverse=True)
      .head(12)
      .collect()
    )

    predictions = " ".join(map(str, most_popular['article_id'].to_list()))

    df = pl.DataFrame({
      'customer_id': customer_ids,
      'prediction': [predictions] * len(customer_ids),
    })

    return df

# %%
sample_submission = pl.read_csv('data/sample_submission.csv')

# %%
transactions.select([pl.max('t_dat').alias('max_date'), pl.min('t_dat').alias('min_date')])
# Out:
# shape: (1, 2)
# ┌──────────┬──────────┐
# │ max_date ┆ min_date │
# │ ---      ┆ ---      │
# │ str      ┆ str      │
# ╞══════════╪══════════╡
# │ null     ┆ null     │
# └──────────┴──────────┘

# %%
rec = MostPopularRecommender(transactions)
submission = rec.get_recommendations(sample_submission['customer_id'], '2018-09-20', '2020-09-23')

# %%
submission
# Out:
# shape: (1371980, 2)
# ┌─────────────────────────────────────┬─────────────────────────────────────┐
# │ customer_id                         ┆ prediction                          │
# │ ---                                 ┆ ---                                 │
# │ str                                 ┆ str                                 │
# ╞═════════════════════════════════════╪═════════════════════════════════════╡
# │ 00000dbacae5abe5e23885899a1fa442... ┆ 0706016001 0706016002 0372860001... │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 0000423b00ade91418cceaf3b26c6af3... ┆ 0706016001 0706016002 0372860001... │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 000058a12d5b43e67d225668fa1f8d61... ┆ 0706016001 0706016002 0372860001... │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 00005ca1c9ed5f5146b52ac8639a40ca... ┆ 0706016001 0706016002 0372860001... │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...                                 ┆ ...                                 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ffffcd5046a6143d29a04fb8c424ce49... ┆ 0706016001 0706016002 0372860001... │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ffffcf35913a0bee60e8741cb2b4e78b... ┆ 0706016001 0706016002 0372860001... │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ffffd7744cebcf3aca44ae7049d2a94b... ┆ 0706016001 0706016002 0372860001... │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ffffd9ac14e89946416d80e791d06470... ┆ 0706016001 0706016002 0372860001... │
# └─────────────────────────────────────┴─────────────────────────────────────┘

# %%
submission.write_csv('most-popular-submission.csv')

# %%
submission2 = rec.get_recommendations(sample_submission['customer_id'], '2020-09-14', '2020-09-23')
submission2.write_csv('most-popular-recent-submission.csv')

# %%
transactions['article_id']
# Out:
# shape: (31788324,)
# Series: 'article_id' [str]
# [
# 	"0663713001"
# 	"0541518023"
# 	"0505221004"
# 	"0685687003"
# 	"0685687004"
# 	"0685687001"
# 	"0505221001"
# 	"0688873012"
# 	"0501323011"
# 	"0598859003"
# 	"0688873020"
# 	"0688873011"
# 	...
# 	"0791587021"
# 	"0910949002"
# 	"0701472004"
# 	"0456163087"
# 	"0832505003"
# 	"0902288001"
# 	"0856440002"
# 	"0929511001"
# 	"0891322004"
# 	"0918325001"
# 	"0833459002"
# 	"0898573003"
# ]
